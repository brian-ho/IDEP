# %%
import os
from PIL import Image
from IPython.display import Image 
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd

# %%
def f(x):
    return Image(images[x%2])

# %%
interact(f, x=10);
# Out:
# A Jupyter Widget

# %%
images = ['kl_images/3341809309.jpg', 'kl_images/3341809381.jpg']

# %%
im = Image.open("kl_images/3341809309.jpg")
im.rotate(45).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-5ace6907e504> in <module>()
# ----> 1 im = Image.open("kl_images/3341809309.jpg")
#       2 im.rotate(45).show()
#
# AttributeError: type object 'Image' has no attribute 'open'

# %%
Image(filename='kl_images/3341809309.jpg')
